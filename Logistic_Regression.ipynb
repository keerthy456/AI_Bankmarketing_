# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import random

data = pd.read_csv('/content/sample_data/AIphase1.csv')

dataset = np.genfromtxt('/content/sample_data/AIphase1.csv',delimiter=',',skip_header=True)
np.set_printoptions(formatter={'float':'{:0.1f}'.format})
np.random.shuffle(dataset)
#loading data set
X = dataset[:,:-1]
Y = dataset[:,-1]
# Out:
# [4.0 4.0 4.0 ... 10.0 3.0 3.0]
# [-0.3 -0.3 -0.3 ... 2.3 -0.7 -0.7]

# %%
m = X.mean(axis=0)
X-=m
s = X.std(axis=0)
X/=s

# %%
#Data Spliting
np.random.shuffle(dataset)
index = int(0.3*len(dataset[:,0]))

XVALID = X[:index,:]
YVALID = Y[:index]
XTRAIN = X[index:,:]
YTRAIN = Y[index:]

# %%
#6-layer NN(8-2,4-3,1), 128 epochs
#NNmodel
model = Sequential()
model.add(Dense(8, input_dim = 20,activation='relu'))
model.add(Dense(8,activation='relu'))
model.add(Dense(4,activation = 'relu'))
model.add(Dense(4,activation = 'relu'))
model.add(Dense(4,activation = 'relu'))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])

# %%
history = model.fit(XTRAIN, YTRAIN, validation_data=(XVALID, YVALID), epochs=128, verbose=1)
# Out:
# Epoch 1/128
# 901/901 [==============================] - 2s 2ms/step - loss: 0.3519 - accuracy: 0.8872 - val_loss: 0.3546 - val_accuracy: 0.8875
# Epoch 2/128
# 901/901 [==============================] - 1s 2ms/step - loss: 0.3519 - accuracy: 0.8872 - val_loss: 0.3545 - val_accuracy: 0.8875
# Epoch 3/128
# 901/901 [==============================] - 1s 2ms/step - loss: 0.3519 - accuracy: 0.8872 - val_loss: 0.3559 - val_accuracy: 0.8875
# Epoch 4/128
# 901/901 [==============================] - 1s 2ms/step - loss: 0.3519 - accuracy: 0.8872 - val_loss: 0.3545 - val_accuracy: 0.8875
# Epoch 5/128
# 901/901 [==============================] - 1s 2ms/step - loss: 0.3519 - accuracy: 0.8872 - val_loss: 0.3545 - val_accuracy: 0.8875
# Epoch 6/128
# 901/901 [==============================] - 1s 2ms/step - loss: 0.3517 - accuracy: 0.8872 - val_loss: 0.3546 - val_accuracy: 0.8875
# Epoch 7/128
# ...

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('epoch')
plt.legend(['training data', 'validation data'], loc='lower right')
plt.show()

# %%
#6-layer NN(8-2,4-3,1), 128 epochs
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('epoch')
plt.legend(['training data', 'validation data'], loc='lower right')
plt.show()

# %%
#6-layer NN(8-2,4-3,1), 256 epochs
model = Sequential()
model.add(Dense(8, input_dim = 20,activation='relu'))
model.add(Dense(8,activation='relu'))
model.add(Dense(4,activation='relu'))
model.add(Dense(4,activation='relu'))
model.add(Dense(4,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])
history = model.fit(XTRAIN,YTRAIN, validation_data= (XVALID, YVALID), epochs=256, verbose=1)
# Out:
# Epoch 1/256
# 901/901 [==============================] - 3s 2ms/step - loss: 0.3500 - accuracy: 0.8873 - val_loss: 0.2340 - val_accuracy: 0.8870
# Epoch 2/256
# 901/901 [==============================] - 2s 2ms/step - loss: 0.2194 - accuracy: 0.8932 - val_loss: 0.2181 - val_accuracy: 0.9050
# Epoch 3/256
# 901/901 [==============================] - 2s 2ms/step - loss: 0.2017 - accuracy: 0.9084 - val_loss: 0.2119 - val_accuracy: 0.9070
# Epoch 4/256
# 901/901 [==============================] - 2s 2ms/step - loss: 0.1978 - accuracy: 0.9086 - val_loss: 0.2077 - val_accuracy: 0.9088
# Epoch 5/256
# 901/901 [==============================] - 2s 2ms/step - loss: 0.1954 - accuracy: 0.9097 - val_loss: 0.2053 - val_accuracy: 0.9088
# Epoch 6/256
# 901/901 [==============================] - 2s 2ms/step - loss: 0.1909 - accuracy: 0.9102 - val_loss: 0.2025 - val_accuracy: 0.9085
# Epoch 7/256
# ...

# %%
#6-layer NN(8-2,4-3,1), 256 epochs
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('epoch')
plt.legend(['training data', 'validation data'], loc='lower right')
plt.show()

# %%
#6-layer NN(8-2,4-3,1), 512 epochs
model = Sequential()
model.add(Dense(8, input_dim = 20,activation='relu'))
model.add(Dense(8,activation='relu'))
model.add(Dense(4,activation='relu'))
model.add(Dense(4,activation='relu'))
model.add(Dense(4,activation = 'relu'))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])
history = model.fit(XTRAIN,YTRAIN, validation_data= (XVALID, YVALID), epochs=1024, verbose=1)
# Out:
# Epoch 1/1024
# 901/901 [==============================] - 3s 2ms/step - loss: 0.3681 - accuracy: 0.8905 - val_loss: 0.2265 - val_accuracy: 0.9028
# Epoch 2/1024
# 901/901 [==============================] - 2s 2ms/step - loss: 0.2132 - accuracy: 0.9038 - val_loss: 0.2204 - val_accuracy: 0.9026
# Epoch 3/1024
# 901/901 [==============================] - 2s 2ms/step - loss: 0.2060 - accuracy: 0.9056 - val_loss: 0.2169 - val_accuracy: 0.9052
# Epoch 4/1024
# 901/901 [==============================] - 2s 2ms/step - loss: 0.2019 - accuracy: 0.9085 - val_loss: 0.2139 - val_accuracy: 0.9059
# Epoch 5/1024
# 901/901 [==============================] - 2s 2ms/step - loss: 0.1981 - accuracy: 0.9104 - val_loss: 0.2102 - val_accuracy: 0.9065
# Epoch 6/1024
# 901/901 [==============================] - 2s 2ms/step - loss: 0.1990 - accuracy: 0.9097 - val_loss: 0.2096 - val_accuracy: 0.9074
# Epoch 7/1024
# ...

# %%
#6-layer NN(8-2,4-3,1), 512 epochs
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('epoch')
plt.legend(['training data', 'validation data'], loc='lower right')
plt.show()

# %%
model = Sequential()
model.add(Dense(16, input_dim = 20,activation='relu'))
model.add(Dense(8,activation='relu'))
model.add(Dense(4,activation='relu'))
model.add(Dense(2,activation='relu'))
model.add(Dense(2,activation='relu'))
model.add(Dense(2,activation='relu'))
model.add(Dense(2,activation='relu'))
model.add(Dense(2,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])
history = model.fit(XTRAIN,YTRAIN, validation_data= (XVALID, YVALID), epochs=64, verbose=1)
# Out:
# Epoch 1/64
# 901/901 [==============================] - 3s 2ms/step - loss: 0.5242 - accuracy: 0.8898 - val_loss: 0.2230 - val_accuracy: 0.8828
# Epoch 2/64
# 901/901 [==============================] - 2s 2ms/step - loss: 0.2141 - accuracy: 0.8893 - val_loss: 0.2128 - val_accuracy: 0.9077
# Epoch 3/64
# 901/901 [==============================] - 2s 2ms/step - loss: 0.2003 - accuracy: 0.9073 - val_loss: 0.2065 - val_accuracy: 0.9085
# Epoch 4/64
# 901/901 [==============================] - 2s 2ms/step - loss: 0.1931 - accuracy: 0.9092 - val_loss: 0.2028 - val_accuracy: 0.9083
# Epoch 5/64
# 901/901 [==============================] - 2s 2ms/step - loss: 0.1932 - accuracy: 0.9097 - val_loss: 0.2057 - val_accuracy: 0.9088
# Epoch 6/64
# 901/901 [==============================] - 2s 2ms/step - loss: 0.1867 - accuracy: 0.9117 - val_loss: 0.1987 - val_accuracy: 0.9098
# Epoch 7/64
# ...

# %%
#6-layer NN(8-2,4-3,1), 512 epochs
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('epoch')
plt.legend(['training data', 'validation data'], loc='lower right')
plt.show()

# %%
model = Sequential()
model.add(Dense(16, input_dim = 20,activation='relu'))
model.add(Dense(8,activation='relu'))
model.add(Dense(4,activation='relu'))
model.add(Dense(2,activation='relu'))
model.add(Dense(2,activation='relu'))
model.add(Dense(2,activation='relu'))
model.add(Dense(2,activation='relu'))
model.add(Dense(2,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])
history = model.fit(XTRAIN,YTRAIN, validation_data= (XVALID, YVALID), epochs=15, verbose=1)
# Out:
# Epoch 1/15
# 901/901 [==============================] - 3s 2ms/step - loss: 0.4265 - accuracy: 0.8872 - val_loss: 0.2178 - val_accuracy: 0.8862
# Epoch 2/15
# 901/901 [==============================] - 2s 2ms/step - loss: 0.2074 - accuracy: 0.9029 - val_loss: 0.2081 - val_accuracy: 0.9032
# Epoch 3/15
# 901/901 [==============================] - 2s 2ms/step - loss: 0.1942 - accuracy: 0.9118 - val_loss: 0.2057 - val_accuracy: 0.9028
# Epoch 4/15
# 901/901 [==============================] - 2s 2ms/step - loss: 0.1903 - accuracy: 0.9124 - val_loss: 0.2054 - val_accuracy: 0.9051
# Epoch 5/15
# 901/901 [==============================] - 2s 2ms/step - loss: 0.1930 - accuracy: 0.9079 - val_loss: 0.2030 - val_accuracy: 0.9052
# Epoch 6/15
# 901/901 [==============================] - 2s 2ms/step - loss: 0.1913 - accuracy: 0.9125 - val_loss: 0.2033 - val_accuracy: 0.9062
# Epoch 7/15
# ...
